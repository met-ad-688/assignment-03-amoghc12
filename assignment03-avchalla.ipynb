# %% [markdown]
# ---
# title: Assignment 03
# author:
#   - name: Norah Jones
#     affiliations:
#       - id: bu
#         name: Boston University
#         city: Boston
#         state: MA
# number-sections: true
# date: '2024-11-21'
# format:
#   html:
#     theme: cerulean
#     toc: true
#     toc-depth: 2
# date-modified: today
# date-format: long
# execute:
#   echo: false
#   eval: false
#   freeze: auto
# ---
